# %% [markdown]
# # 📊 DỰ ÁN 1 — XÂY DỰNG MÔ HÌNH PHÂN LOẠI VÀ DỰ BÁO RỦI RO KHÁCH HÀNG VAY VỐN
#
# **Notebook 07/07 — Prediction Demo (Demo dự đoán)**
#
# ---
#
# **🎯 Mục tiêu:** Demo dự đoán rủi ro trên hồ sơ khách hàng mới bằng mô hình đã huấn luyện; minh họa luồng dự đoán sẽ dùng trong app Streamlit.
#
# **📥 Input:** `models/model.pkl`, `models/scaler.pkl` + dữ liệu mẫu
#
# **📤 Output:** Kết quả dự đoán minh họa cho app Streamlit (`app/`).
#
# **🔗 Pipeline:** 06. Machine Learning → **07. Prediction Demo** → *(app Streamlit)*
